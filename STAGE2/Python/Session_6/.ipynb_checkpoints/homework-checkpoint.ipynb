# %% [markdown]
# # Pandas homework

# %% [markdown]
# Please use folder source_files folder for source csv files, output_files folder for files that you will export during you homework (tasks ):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Source_files foder should looks like:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Output_files folder should looks like:
# ![image.png](attachment:image.png)

# %% [markdown]
# Please do not change test cells, just run them after you write you code and check if the result is correct.

# %%
import os
import pandas as pd
import numpy as np

# Add other needed imports here:
import pandavro as pdx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 6
#       3 import numpy as np
#       5 # Add other needed imports here:
# ----> 6 import pandavro as pdx
#
# ModuleNotFoundError: No module named 'pandavro'

# %%
PATH_TO_SALES = "./source_files/sales.csv"
PATH_TO_HOUSES = "./source_files/houses.csv"
PATH_TO_EMPLOYEES = "./source_files/employees.csv"

# %% [markdown]
# ### 1. Create 3 Dataframes(sales, houses, employees) for csv files

# %%
# Add your code here
sales = pd.read_csv(PATH_TO_SALES)
houses = pd.read_csv(PATH_TO_HOUSES)
employees = pd.read_csv(PATH_TO_EMPLOYEES)

# %%
assert 993112 == len(sales), (
    "Incorrect size of sales DataFrame"
)
assert 1019875 == len(houses), (
    "Incorrect size of houses DataFrame"
)
assert 870 == len(employees), (
    "Incorrect size of employees DataFrame"
)
assert (['LOCATION_ID', 'HOUSE_ID', 'DATERECORDED', 'BRANCH_ID', 'CUSTOMER_ID',
       'COST', 'SALEAMOUNT', 'PAYMENT_TYPE_ID', 'PAYMENT_TYPE', 'EMP_ID'] == sales.columns).all(), (
    "Incorrect column names for sales DataFrame"
)
assert (['HOUSE_ID', 'HOUSE_NAME', 'HOUSE_CATEGORY_ID', 'HOUSE_CATEGORY',
       'HOUSE_SUBCATEGORY_ID', 'HOUSE_SUBCATEGORY', 'SQUARE', 'PRICE',
       'LOCATION_ID', 'UPDATE_DT'] == houses.columns).all(), (
    "Incorrect column names for houses DataFrame"
)
assert (['EMP_ID', 'EMP_FIRST_NAME', 'EMP_LAST_NAME', 'EMP_GENDER',
       'EMP_DATE_BIRTH', 'EMP_START_DATE', 'EMP_BRANCH'] == employees.columns).all(), (
    "Incorrect column names for employees DataFrame"
)
print("Tests were passed")
# Out:
# Tests were passed

# %% [markdown]
# ###  2. Extract employee first name/last name from 3 to 10 rows(including) from Employees

# %%
# Add your code here
names = employees.loc[3:10,["EMP_FIRST_NAME", "EMP_LAST_NAME"]]

# %%
assert "Shelia" == names.iloc[0]['EMP_FIRST_NAME'], (
    "Incorrect name of first person"
)
assert "Larchier" == names.iloc[0]['EMP_LAST_NAME'], (
    "Incorrect surname of first person"
)
assert "Andonis" == names.iloc[7]['EMP_FIRST_NAME'], (
    "Incorrect name of last person"
)
assert "Muress" == names.iloc[7]['EMP_LAST_NAME'], (
    "Incorrect surname of last person"
)
print("Tests were passed")
# Out:
# Tests were passed

# %% [markdown]
# ### 3. Get amount of men/women among all employees (Please use function value_counts())

# %%
# Add your code here
amount_by_gender = employees["EMP_GENDER"].value_counts()
print(amount_by_gender)
# Out:
# EMP_GENDER
# M    436
# F    434
# Name: count, dtype: int64

# %%
assert (amount_by_gender.index[0] == "M") and (amount_by_gender[0] == 436), (
    "Incorrect number of men"
)
assert (amount_by_gender.index[1] == "F") and (amount_by_gender[1] == 434), (
    "Incorrect number of women"
)
print("Tests were passed")
# Out:
# Tests were passed
# /var/folders/w5/t0hgtlzx2zsdfkp__3x07gph0000gq/T/ipykernel_3996/3743019985.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert (amount_by_gender.index[0] == "M") and (amount_by_gender[0] == 436), (
# /var/folders/w5/t0hgtlzx2zsdfkp__3x07gph0000gq/T/ipykernel_3996/3743019985.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert (amount_by_gender.index[1] == "F") and (amount_by_gender[1] == 434), (

# %% [markdown]
# ### 4. Fill empty cells by 0 in column “square” in houses dataframe

# %%
# Add you code here (change 'houses' DataFrame directly)
houses["SQUARE"] = houses["SQUARE"].fillna(0)

# %%
assert len(houses[houses["SQUARE"].isna()]) == 0, (
    "There are empty cells on square columns"
)
print("Test was passed")
# Out:
# Test was passed

# %% [markdown]
# ### 5. Create new column “UNIT_PRICE” for price/1m2 (Please use the following formula: price/square) + round the result to 2 digits after point. Use -1 for "UNIT_PRICE" in case square = 0

# %%
# Add you code here (add new column to 'houses' DataFrame directly)
houses['UNIT_PRICE'] = houses.apply(
    lambda row: round(row['PRICE'] / row['SQUARE'], 2) if row['SQUARE'] > 0 else -1,
    axis=1
)
# Out:
#          HOUSE_ID           HOUSE_NAME  HOUSE_CATEGORY_ID   HOUSE_CATEGORY  \
# 0             808    flat  BENZ1849371               1007      residential
# 1             813         flat  N 2817               1007      residential
# 2             843     sweet  DA1880388               1007      residential
# 3             851  sweet  1/2 687143 b               1007      residential
# 4             852       flat  189612 b               1007      residential
# ...           ...                  ...                ...              ...
# 1019870    269264    hot  HOBAR2485626               1008  non-residential
# 1019871    269901          low  392403               1008  non-residential
# 1019872    271110       flat   1216845               1007      residential
# 1019873    271675     soft   KN1521968               1007      residential
# 1019874    273493  well  MASO1333940 b               1007      residential
#
#          HOUSE_SUBCATEGORY_ID    HOUSE_SUBCATEGORY  SQUARE   PRICE  \
# 0                           6   single-family flat    44.0   88660
# 1                           4  single-family house    68.0  141848
# 2                           6   single-family flat    69.0  139035
# 3                           6   single-family flat    61.0  122915
# 4                           6   single-family flat    76.0  153140
# ...                       ...                  ...     ...     ...
# 1019870                     1                stock    53.0   94976
# 1019871                     1                stock   100.0  179200
# 1019872                     4  single-family house    87.0  181482
# 1019873                     4  single-family house   111.0  231546
# 1019874                     4  single-family house   101.0  210686
#
#          LOCATION_ID UPDATE_DT  UNIT_PRICE
# 0              808.0  1-Jan-14      2015.0
# 1              813.0  1-Jan-14      2086.0
# 2              843.0  1-Jan-14      2015.0
# 3              851.0  1-Jan-14      2015.0
# 4              852.0  1-Jan-14      2015.0
# ...              ...       ...         ...
# 1019870     268804.0  1-Jan-14      1792.0
# 1019871     269441.0  1-Jan-14      1792.0
# 1019872     270649.0  1-Jan-14      2086.0
# 1019873     271214.0  1-Jan-14      2086.0
# 1019874     273031.0  1-Jan-14      2086.0
#
# [1019875 rows x 11 columns]

# %%
assert ('UNIT_PRICE' in houses) == True, (
    "UNIT_PRICE column is missed in houses DataFrame"
)
assert houses['UNIT_PRICE'].iloc[0] == 2015, (
    "UNIT_PRICE column is calculated incorrectly in houses DataFrame"
)
assert houses['UNIT_PRICE'].iloc[31] == 2015.00, (
    "Incorrect rounding for UNIT_PRICE column in houses DataFrame"
)
assert houses['UNIT_PRICE'].iloc[20] == -1, (
    "Incorrect value for UNIT_PRICE column in houses DataFrame in case SQUARE column = 0"
)
print("Tests were passed")
# Out:
# Tests were passed

# %% [markdown]
# ### 6. Sort houses dataframe by price descending; put the result to json file ('output_files/task_6.json').

# %%
# Add you code here
sorted_houses = houses.sort_values(by='PRICE', ascending=False)
sorted_houses.to_json('output_files/task_6.json')

# %%
assert houses["PRICE"].iloc[-1] == 30400, (
    "Incorrect sorting"
)
assert houses["PRICE"].iloc[0] == 558600, (
    "Incorrect sorting"
)
assert os.path.exists('./output_files/task_6.json') == True, (
    "No task_6.json file in the output_files folder"
)
print("Tests were passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 assert houses["PRICE"].iloc[-1] == 30400, (
#       2     "Incorrect sorting"
#       3 )
#       4 assert houses["PRICE"].iloc[0] == 558600, (
#       5     "Incorrect sorting"
#       6 )
#       7 assert os.path.exists('./output_files/task_6.json') == True, (
#       8     "No task_6.json file in the output_files folder"
#       9 )
#
# AssertionError: Incorrect sorting

# %% [markdown]
# ### 7. Please filter employees dataframe and find how much women with name ‘Vera’ we have

# %%
# Add you code here
employees_filtered = employees[employees['EMP_FIRST_NAME'] == 'Vera']

# %%
assert len(employees_filtered) == 1, (
    "Incorrect number of women"
)
print("Test was passed")
# Out:
# Test was passed

# %% [markdown]
# ### 8. Please count (size()) how many houses do we have with square >= 100 m2, group by category and subcategory.

# %%
#Add you code here
df = houses[houses['SQUARE'] >= 100]
df = df.groupby(['HOUSE_CATEGORY', 'HOUSE_SUBCATEGORY']).size()
print(df)
# Out:
# HOUSE_CATEGORY   HOUSE_SUBCATEGORY
# non-residential  office                  1150
#                  stock                  29644
# residential      duplex house           70076
#                  single-family house    86618
# dtype: int64

# %%
assert df[0] == 1150, (
    "Incorrect count"
)
assert df[1] == 29644, (
    "Incorrect count"
)
assert df[2] == 70076, (
    "Incorrect count"
)
assert df[3] == 86618, (
    "Incorrect count"
)
assert df.index[0]==('non-residential','office'), (
    "Incorrect group by columns"
)
assert df.index[1]==('non-residential','stock'), (
    "Incorrect group by columns"
)
assert df.index[2]==('residential','duplex house'), (
    "Incorrect group by columns"
)
assert df.index[3]==('residential','single-family house'), (
    "Incorrect group by columns"
)
print("Tests were passed")
# Out:
# Tests were passed
# /var/folders/w5/t0hgtlzx2zsdfkp__3x07gph0000gq/T/ipykernel_3996/2856363472.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert df[0] == 1150, (
# /var/folders/w5/t0hgtlzx2zsdfkp__3x07gph0000gq/T/ipykernel_3996/2856363472.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert df[1] == 29644, (
# /var/folders/w5/t0hgtlzx2zsdfkp__3x07gph0000gq/T/ipykernel_3996/2856363472.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert df[2] == 70076, (
# /var/folders/w5/t0hgtlzx2zsdfkp__3x07gph0000gq/T/ipykernel_3996/2856363472.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert df[3] == 86618, (

# %% [markdown]
# ### 9. Put the result from task 7 to file .avro  ('output_files/task_9.avro')

# %%
#Add your code here
#output_file_path = 'output_files/task_9.avro'
#pdx.to_avro(output_file_path, employees_filtered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 3
#       1 #Add your code here
#       2 output_file_path = 'output_files/task_9.avro'
# ----> 3 pdx.to_avro(output_file_path, employees_filtered)
#
# NameError: name 'pdx' is not defined

# %%
assert os.path.exists('./output_files/task_9.avro') == True, (
    "No task_9.avro file in the output_files folder"
)
print("Tests were passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 assert os.path.exists('./output_files/task_9.avro') == True, (
#       2     "No task_9.avro file in the output_files folder"
#       3 )
#       4 print("Tests were passed")
#
# AssertionError: No task_9.avro file in the output_files folder

# %% [markdown]
# ### 10. Please update “SALESAMOUNT” column according to the following rule “SALESAMOUNT” = “SALESAMOUNT” + avg value of SALESAMOUNT*0.02 (Please try to use apply and lambda for it)

# %%
# Add your code here
avg_increase = sales['SALEAMOUNT'].mean() * 0.02
sales['SALEAMOUNT'] = sales['SALEAMOUNT'].apply(lambda x: x + avg_increase)

# %%
assert sales['SALEAMOUNT'][0] == 52000.740744939336, (
    "Value in SALESAMOUNT column is incorrect after update"
)
print("Test was passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 assert sales['SALEAMOUNT'][0] == 52000.740744939336, (
#       2     "Value in SALESAMOUNT column is incorrect after update"
#       3 )
#       4 print("Test was passed")
#
# AssertionError: Value in SALESAMOUNT column is incorrect after update

# %% [markdown]
# ### 11. Please find all houses that are unsold yet (exists in houses but does not exist in sales, join by house_id). Put house ids to .json ('output_files/task_11.json'). Put result list of unique house names into house_ids_available list

# %%
# Add your code here
unsold_houses = houses[~houses['HOUSE_ID'].isin(sales['HOUSE_ID'])]
unsold_houses[['HOUSE_ID']].to_json('output_files/task_11.json', orient='records')
house_ids_available = unsold_houses['HOUSE_NAME'].unique().tolist()

# Put result list of unique house names into house_ids_available list
house_ids_available
# Out:
# ['good   LIVE2477845 5',
#  'low  TI2060031 4',
#  'warm  WO163814 5',
#  'good  BUR2394903 a',
#  'warm   BOU1520174',
#  'low  WH1099434',
#  'flat  INDE2440608',
#  'well   MAR2275027',
#  'hot  FREES151188',
#  'soft   ASH 1056768',
#  'full   YELL1853707',
#  'BEAUTI   SA883139',
#  'far  NO1304168 5',
#  'warm  TR1972416',
#  'hot  357925',
#  'far  COLU342354 4',
#  'warm  H1104272',
#  'pleasant   T321709',
#  'far  FLANN2387013',
#  'BEAUTI  CURRY2637774 a',
#  'low  E HI694177',
#  'well  WO594532 4',
#  'good   1751655',
#  'flat   B2002687',
#  'sweet  MID1928602',
#  'warm   1597957',
#  'rich   1533030',
#  'BIG   1710980',
#  'flat  E HIG399478 5',
#  'soft  B2624217 5',
#  'hot  CURRY2213576',
#  'well  TARRA1135806',
#  'soft  N M2151856',
#  'far  NOR2483605 5',
#  'LARGE  MIDDL710606',
#  'good   TENN415462',
#  'far   SHE1979088',
#  'good  BARB114380',
#  'soft  BIR1790673',
#  'LARGE  1852454',
#  'full  HI1229352 4',
#  'full  SOU953146 5',
#  'good  BL756629 4',
#  'BEAUTI  737842',
#  'BEAUTI  ROC635696',
#  'pleasant  1261257',
#  'LARGE  BRADL1460990 b',
#  'low  CON1172090 4',
#  'flat  LAWR399784 b',
#  'well  10005 5',
#  'far  HIL1467777',
#  'low  TOLLA52460',
#  'sweet  805778 a',
#  'full  TOLL1754786 4',
#  'well  TOL1359596 5',
#  'warm  TO1247534',
#  'well  TOL1903923',
#  'LARGE  87949 5',
#  'sweet  B1674774',
#  'well  FR1726415',
#  'BIG  NASSA242865 5',
#  'hot  1068666 4',
#  "low  O'C1258917",
#  'pleasant  LE2280116 b',
#  'LARGE  L1679518',
#  'rich  603548 4',
#  'flat  RUMSE2314955',
#  'flat  T2233788',
#  'low  MAI1703486',
#  'soft  MAIN 1948695 5',
#  'far  M912780',
#  'sweet  MAIN 1236158',
#  'pleasant  M1026291',
#  'soft  MAIN 2158589 4',
#  'lucky  MAIN 328743',
#  'low  T446943',
#  'flat  1534522',
#  'hot  HAN1291900 5',
#  'pleasant  MOUNT254871',
#  'well  FRAN2146611',
#  'far  J1965189',
#  'far  RIS533671 4',
#  'sweet  STRO1643084',
#  'BEAUTI  WAKEF353598',
#  'hot  BURNS1491526',
#  'pleasant  PARK 2436446',
#  'flat  GR1373370',
#  'sweet  GRE2605794 a',
#  'far  MANNI1267707',
#  'well  WH51536',
#  'full  B2474882',
#  'soft  HIL2012121',
#  'well  BUR1466624',
#  'warm  PARK1749708',
#  'good  B899339',
#  'BEAUTI   WOOD816734 5',
#  'pleasant  1758141',
#  'warm   O2367512',
#  'full   AL673602',
#  'low  MOO1278263',
#  'low  2583494',
#  'far   E H149236',
#  'pleasant  903331 5',
#  'hot   400484',
#  'hot  PARK951127 b',
#  'full   240188',
#  'far  GREE521601',
#  'LARGE   15 351521 a',
#  'LARGE  MID2443231 5',
#  'soft   O2450385',
#  'BEAUTI  2128879',
#  'sweet  1726927 4',
#  'low   LI2430117 5',
#  'lucky  SCU1461038',
#  'lucky   806486 4',
#  'hot   1607617',
#  'good  S1801395',
#  'soft  2240089',
#  'lucky  159849',
#  'hot  SAMP2310432',
#  'hot  1979026',
#  'flat   PEM1794925',
#  'lucky   1517841',
#  'soft  MIL1479759',
#  'flat  MI2372282 4',
#  'BEAUTI  WES1977651 4',
#  'lucky   HEAR2106575 b',
#  'hot   C804358 b',
#  'flat  232049',
#  'full  B1076457',
#  'pleasant   2220276 b',
#  'sweet   C1068102 b',
#  'warm  DEAN 1842547',
#  'flat  DIV2363279 b',
#  'LARGE   FA2430824',
#  'BEAUTI  CARRI2548057 b',
#  'flat  DAN1452277',
#  'lucky   SCUP1268175',
#  'good  SHAN824451',
#  'flat  E579897',
#  'warm  1497331 a',
#  'flat  863905 4',
#  'BEAUTI  CAN1143975 a',
#  'sweet  GOOD1924214 b',
#  'BEAUTI  2493999 4',
#  'hot  GRE1215704',
#  'BEAUTI  AMAT1052178 4',
#  'soft  F1720546',
#  'hot  WHI1357982',
#  'lucky  2631766 a',
#  'BEAUTI  HOME 1178776 4',
#  'low  HO1619730',
#  'hot  L13857',
#  'full  PHIL2076412',
#  'well  PRINC627537',
#  'low  WESTE1936263',
#  'BIG  CANDL2074130 5',
#  'lucky  HILL502804 5',
#  'LARGE  2310517',
#  'BEAUTI  PA2256400',
#  'well  PO775038 4',
#  'pleasant  SCOT1636112 4',
#  'LARGE  SCOT1229919 b',
#  'well  T1548074 4',
#  'BEAUTI  BURN529406',
#  'warm  BU1140387',
#  'good  BUR621801 a',
#  'low  606970 5',
#  'low  1731644',
#  'warm  BE1380929',
#  'pleasant  BIS1243892',
#  'sweet  2554257 b',
#  'full  2292294',
#  'full  F704566',
#  'LARGE  HIL656559',
#  'full  WHITI1263827',
#  'good  1676899',
#  'warm  62931',
#  'pleasant  CONN1044398 5',
#  'soft  OA61870',
#  'good  2116820 4',
#  'low  BO2591206',
#  'soft  MALLA806226',
#  'flat  835573 4',
#  'lucky  1658771 4',
#  'BEAUTI  HIGBI1891388 5',
#  'good  S183420 5',
#  'well  872147',
#  'well  HI1393331',
#  'LARGE   678716 5',
#  'sweet  493697',
#  'flat  PA1793067',
#  'well  SH1447005',
#  'low   WHIT2263120',
#  'warm  468547 b',
#  'lucky   1492465 a',
#  'LARGE   O351507 b',
#  'far  R1294235',
#  'warm  WIND1103443 b',
#  'hot  1444439',
#  'BEAUTI  MEADO462285 5',
#  'LARGE   2183425',
#  'soft  CENT1892793',
#  'low  CENT1114381',
#  'pleasant   393034',
#  'sweet  V1746468',
#  'BEAUTI  CEDAR1396914',
#  'LARGE  CA143557',
#  'full  TR1149053',
#  'low   R1762670',
#  'BEAUTI   WOOD2602104',
#  'LARGE  MAURA1377309 b',
#  'LARGE   LA1439728',
#  'hot   652629 4',
#  'lucky   E P2628340 b',
#  'sweet  CEDAR1201715 5',
#  'LARGE  1674388',
#  'far  478324',
#  'far  147342',
#  'LARGE  K1877271 4',
#  'soft  1697428 5',
#  'sweet  P195081',
#  'LARGE  RD2347522',
#  'flat  2414037 4',
#  'rich  AVE1152354 4',
#  'rich  ST 21924957 4',
#  'warm  RVR1489873',
#  'low  RD 271145448 5',
#  'lucky  POI1177718 4',
#  'far  DR 167038 b',
#  'sweet  DR 2195891',
#  'far  2147395 4',
#  'good  PA2346366 b',
#  'full  PA1072952 4',
#  'warm  P2042630',
#  'flat  PAR124780',
#  'LARGE  PA519940',
#  'warm  RD 73844047',
#  'BEAUTI  P1947069 4',
#  'lucky  LIL1038896',
#  'LARGE  SI1278150 4',
#  'far   RIV2473810',
#  'pleasant  MAIN 1175745 4',
#  'full  W212461',
#  'hot  MAIN 408502 4',
#  'good  MA2121574 5',
#  'warm   CE1120817',
#  'lucky   RD1704423 a',
#  'soft  HU580903 b',
#  'warm  RI481200 4',
#  'good  MAI2537118',
#  'LARGE  SP2279923',
#  'BIG  MA2256585',
#  'full   HILL764079',
#  'flat   H2160427 5',
#  'sweet  696694',
#  'warm   146358 a',
#  'flat  CE1436147 4',
#  'far  M1168499',
#  'full  TOW296037',
#  'LARGE   1300429',
#  'soft   MEAD2365680',
#  'lucky  1101873 4',
#  'low   D1797264',
#  'full  1717615 5',
#  'good   P6881 4',
#  'good  P1091923',
#  'sweet   M1484263 5',
#  'warm   2487271 b',
#  'BIG  501068',
#  'hot   E745426',
#  'lucky  F1816976 a',
#  'flat  409700',
#  'LARGE  2351124',
#  'sweet  RATTL1040366 b',
#  'hot  CL420864',
#  'hot  UN1041210',
#  'sweet  RIVER2516152 4',
#  'pleasant  MARIT2633506',
#  'sweet  UNIO644849',
#  'low  MAI964438',
#  'soft  BU491606 4',
#  'far  BU766385 5',
#  'sweet  KI2583708',
#  'lucky  MEAD334297 5',
#  'LARGE  WES558533',
#  'BIG  405963',
#  'lucky  2042765',
#  'pleasant  WEST2252734',
#  'well  WI1767574',
#  'warm  KIRT2147343 4',
#  'far  MAIN 2278158 5',
#  'sweet  2399612',
#  'hot  WI1809699',
#  'good  PIN1030128 5',
#  'sweet  RIVER453331',
#  'LARGE  551508',
#  'warm  FAL644378',
#  'hot  FALLS1599530 5',
#  'sweet  112469',
#  'flat  1113402 b',
#  'sweet  ES982653 4',
#  'flat  L451004',
#  'hot  BRIDG654678',
#  'lucky  1958853',
#  'sweet  2218829',
#  'LARGE  MER85335',
#  'soft  SPRI111286',
#  'sweet  KIRT1199625 4',
#  'low  BUR2325060 5',
#  'low  UN35983',
#  'pleasant  BR811995 4',
#  'well  MA589239 b',
#  'far  MAIN 1581816 5',
#  'sweet  MA82352 b',
#  'far  MA490229',
#  'LARGE  MAI1756023',
#  'low  408971 4',
#  'low  WINT2405451 b',
#  'sweet  403929 a',
#  'full  W108771',
#  'sweet  RIV868392 b',
#  'flat  ST765734',
#  'well  597901',
#  'BIG  GROV1897487',
#  'sweet   S1045227 5',
#  'BEAUTI  542124',
#  'BIG  WINT942489',
#  'good  2177806',
#  'LARGE  CED27460 5',
#  'BEAUTI   SHAI847247 5',
#  'far  MA1709166',
#  'low  BEL2461018 4',
#  'sweet  SHA1007378',
#  'low   1275713',
#  'low   BRI1551547',
#  'BEAUTI  DEER1299393',
#  'pleasant  PEN1710545 5',
#  'full  STA2087479 a',
#  'warm  SU1070021 5',
#  'sweet  OA1523701 4',
#  'BIG  RIV1462292 5',
#  'flat  NO541042 a',
#  'BIG  WE1317055',
#  'lucky  BU1500916',
#  'rich  ST1956922',
#  'pleasant  SCHO1871463 5',
#  'warm  MI1573468 5',
#  'warm  EL1487990',
#  'good  PINE 171040',
#  'far  PROS2083723',
#  'LARGE  859034',
#  'LARGE  JA1176994',
#  'full  129262 b',
#  'LARGE  P1493590',
#  'BIG  1860726',
#  'full  STAN1839547',
#  'flat  THO1021174 a',
#  'far  BU2443151 a',
#  'soft  1013645',
#  'LARGE  2567782',
#  'sweet  CAR1040185',
#  'good  884123',
#  'LARGE  ALEX965182 b',
#  'good  PHOE1885669 4',
#  'good  QU1788177 5',
#  'far  BO1661023 b',
#  'pleasant  BUC468664',
#  'lucky  1705422',
#  'full  1174019 5',
#  'hot  COLC243235',
#  'full  895997 4',
#  'lucky  2078407',
#  'soft  WAT2344905',
#  'LARGE  2344647 b',
#  'warm  BOR838871',
#  'full  1648479 5',
#  'soft  NEL1826169 a',
#  'pleasant  GARY2326700',
#  'soft  1644952',
#  'soft  NO2561513',
#  'far  1021476',
#  'BEAUTI   CO1862993',
#  'soft  ELLI607886 4',
#  'good  OLD 12260 5',
#  'lucky  729627 4',
#  'well  QUA942190 a',
#  'warm  BUC2064578',
#  'pleasant   NEW 270864',
#  'sweet   CAB1940519',
#  'soft   2429234 b',
#  'low   SULL627169 4',
#  'soft  DEERF2400924 5',
#  'LARGE  DANIE597381',
#  'LARGE  N2607626',
#  'sweet  L1254552',
#  'low  CIRI1078980 b',
#  'pleasant  CLARK482924 5',
#  'LARGE  PROSP1086864 4',
#  'soft  1041666 a',
#  'sweet   1992617 b',
#  'sweet  554963',
#  'full  2018923',
#  'well  PRO1225329',
#  'soft  D840530',
#  'low  97377',
#  'far  1839395 b',
#  'full   1429656',
#  'BEAUTI   461800',
#  'full   S1396747',
#  'lucky   1309462',
#  'low  VILL2258354',
#  'sweet   1469070',
#  'far  ALP193063',
#  'full  708185 5',
#  'far   LEB619665 4',
#  'flat   CO222856',
#  'well  BULKE2611718 5',
#  'sweet   MIL1861136',
#  'warm   PROS395425',
#  'low   346261 a',
#  'good   NO1321150 a',
#  'low   W573752 b',
#  'BEAUTI  SKYL1967911 b',
#  'well   RE2196830 5',
#  'warm   BALA2621744 4',
#  'BEAUTI   2115778',
#  'low   900929 5',
#  'hot   C1009645',
#  'hot   NEL558299',
#  'BIG   2360206 b',
#  'good   DAR1106788',
#  'low   CE433154 5',
#  'good  2499530',
#  'soft   ROBI2422687 b',
#  'full   SCOT848778',
#  'full   NO2512004',
#  'pleasant  1107742',
#  'LARGE   2183287 4',
#  'sweet  CHELS183060',
#  'warm   MA1315626 4',
#  'well   WOOD262720 b',
#  'soft  WI1060679',
#  'low   WI2071384',
#  'pleasant   GOOD2402005 5',
#  'warm  B77293',
#  'sweet   HIGH131616',
#  'good   MAG165659 5',
#  'rich  G1631612 a',
#  'well  EVER2011705',
#  'BIG  WO703166',
#  'warm  R1022844',
#  'flat  JUNI1460071 4',
#  'far  1745475 5',
#  'sweet  SPR1851415',
#  'lucky  1060135',
#  'warm  1704874',
#  'hot   TI528930',
#  'low  L556499 5',
#  'low  NO606998',
#  'warm   SU1841577',
#  'well  LOWE1683466',
#  'lucky  V1837476',
#  'low  HIGHR769225 a',
#  'good  WOO47294',
#  'well  CEDA1532320',
#  'soft  JEWEL513413 4',
#  'BEAUTI  RE1551921',
#  'full  96580',
#  'hot  HE377047 5',
#  'good  465246',
#  'LARGE  CRO929889 4',
#  'BIG  S1305845',
#  'hot  C1394376',
#  'sweet  SYDN2163260',
#  'good  C1162664',
#  'far  SALEM405765',
#  'BEAUTI  BA2168366',
#  'soft  983812',
#  'well  W POI2604854',
#  'flat  1184616',
#  'good  MOTT 687817 4',
#  'well  C423824',
#  'pleasant  COM369130 b',
#  'good  WEST1391971',
#  'soft  WE2366860',
#  'rich  CUR862091 b',
#  'sweet  1/2 O2306805 b',
#  'LARGE  MAIN2340226',
#  'pleasant  EAS131030',
#  'LARGE  MYR48398',
#  'rich  N MAP2152692 4',
#  'lucky  OAK K1183151',
#  'low  SPICE1565259 4',
#  'sweet   DAL1353048 5',
#  'full  868400 a',
#  'LARGE  429677',
#  'far  E1822676',
#  'low  CUR566638',
#  'low  ISLA80890',
#  'low  FAIR1530097',
#  'lucky  MI872956',
#  'sweet  MO2294955 5',
#  'good  AB1497127 b',
#  'warm  B1591910 4',
#  'BEAUTI  MAL67422 4',
#  'pleasant  STE118106',
#  'sweet  TAR172538 a',
#  'soft  909460',
#  'sweet  BEA1753815',
#  'pleasant  748326',
#  'sweet  M2200558 a',
#  'good  MOTT1852825',
#  'far  2643116',
#  'pleasant  KNO2104008',
#  'LARGE  MA1856456 b',
#  'pleasant  M188163 5',
#  'LARGE  B1865377 b',
#  'far  N HOL261833',
#  'good  NORTH587179 4',
#  'pleasant  TAMM903625',
#  'warm  2426630',
#  'good  399749',
#  'LARGE  MO2061062',
#  'flat  YO648588',
#  'pleasant  HOG266917',
#  'good  SUNR687531',
#  'well  T120193',
#  'low  598004',
#  'pleasant  LAU342279 4',
#  'hot  C14999 b',
#  'sweet  NO33545',
#  'flat  TA847161 4',
#  'low   281796 4',
#  'soft  CAN2054437',
#  'flat  EASTH2372913 b',
#  'flat  SA1193162',
#  'rich  SEMIN350130',
#  'sweet   1837552 b',
#  'BIG  1035466',
#  'BEAUTI   JA577652 5',
#  'soft  249568',
#  'good  949478',
#  'sweet  753844',
#  'sweet   S1601689',
#  'low  130785',
#  'sweet  863002',
#  'flat  SK847342',
#  'good  H1006634',
#  'flat   WOOD2026939',
#  'BEAUTI  BLAC2293007',
#  'warm  277123',
#  'full  HIGHL1098824 a',
#  'sweet  BRI241550',
#  'BEAUTI   1302447 5',
#  'well   WES1643984',
#  'pleasant   SHAN1573284',
#  'far  H2469523',
#  'soft  CLUB1219432 5',
#  'low  GLE806682 b',
#  'full   LE2064633',
#  'BIG  ME952644',
#  'soft  EDGEW875893 4',
#  'sweet  WO711062',
#  'soft  CO380303',
#  'low  656061 5',
#  'soft  BOXWO1159372 a',
#  'BEAUTI   B2578395 a',
#  'full  C554357',
#  'LARGE   AVE 1737893',
#  'good 472190892',
#  'warm  S870024 b',
#  'BEAUTI  ELL711029',
#  'sweet  CEN1208129',
#  'pleasant  N2358195 b',
#  'lucky  BA2423716',
#  'BEAUTI  PAD398317',
#  'low  PADAN1437008 5',
#  'low  LOCUS1830640 b',
#  'flat  STA1243570',
#  'pleasant   SIE2179362',
#  'well  KO1066549 5',
#  'pleasant  249507',
#  'hot  RAY1022561',
#  'pleasant  MAURA1320182 a',
#  'BEAUTI  CROWS1040250',
#  'sweet   MILL2371770',
#  'BEAUTI  COMST216318',
#  'well   WAR2257461',
#  'lucky  K2027136',
#  'warm  L1534860',
#  'soft  CLAPB546611',
#  'well  W384769 5',
#  'pleasant  MAIN 598332 b',
#  'warm  JEAN1418672 b',
#  'hot   D721846',
#  'full  1417072 b',
#  'far  1963625',
#  'lucky  OLD1041537',
#  'BEAUTI  522540',
#  'lucky   2612321',
#  'pleasant  SU2217443 b',
#  'lucky  161354',
#  'far   2049066',
#  'BEAUTI  AL2146437 4',
#  'flat  2050350',
#  'far   S1078030 b',
#  'rich   1541566',
#  'hot  EL876198 5',
#  'flat   FOX1321673 b',
#  'well  OLD T653237 4',
#  'warm  QUEEN2414923 a',
#  'sweet  2143812',
#  'LARGE   ED1087805 b',
#  'flat   HUNT290395 a',
#  'soft   181099',
#  'good   WIND2612490',
#  'lucky   7 300714 b',
#  'hot  1444921',
#  'well   D V2371067',
#  'pleasant  C1760735 b',
#  'lucky  MAPLE1764434',
#  'hot   C796662',
#  'rich   HA2185556',
#  'lucky   115376',
#  'pleasant  256737',
#  'BEAUTI   V1507811 a',
#  'flat   2257102',
#  'far  WAYN254109 5',
#  'flat  HOLL647312 a',
#  'hot   1509106',
#  'far   CAPI1839554 b',
#  'flat  CAR1194845',
#  'good  WHEEL1868285',
#  'sweet   277744 a',
#  'hot  BLA598269',
#  'far   B315399 5',
#  'hot  1730653 b',
#  'soft  QUI664146',
#  'rich   EAS89494',
#  'well  1100116',
#  'hot   MA619262',
#  'BIG   921893',
#  'flat   P1306164',
#  'warm   CAR125444',
#  'BIG   S501889',
#  'far   EVE183559',
#  'lucky   KEN2529339',
#  'flat  LIN2607973',
#  'LARGE   M606652 4',
#  'sweet   T2321853',
#  'soft  1633491 4',
#  'hot   402467',
#  'BEAUTI  E595070 b',
#  'good  KE1696985 b',
#  'hot  C727292 4',
#  'well  JUN780767 5',
#  'sweet  576843',
#  'BEAUTI  OBTU1852971 4',
#  'LARGE  P362015',
#  'warm  LAU1041355',
#  'low  BONN1929031',
#  'lucky  1853338',
#  'far  1819287 5',
#  'BEAUTI  C113304',
#  'BEAUTI  PRO1561917 5',
#  'sweet  R1409998 4',
#  'well  2582898 b',
#  'low  TOMMY1696936 5',
#  'flat  352592',
#  'BEAUTI  RI975913',
#  'LARGE  GRAYS586874 4',
#  'well  STON137906 b',
#  'lucky  CARR1806202 4',
#  'lucky  HANOV383477 5',
#  'full  HILL2350566 b',
#  'BIG  HI2437571',
#  'LARGE  HOME521612 5',
#  'good  PA1603899 4',
#  'pleasant  PROS1465867',
#  'BIG  LON988822',
#  'full  OBT1088875 b',
#  'well  LONG1598174 b',
#  'good  55368 b',
#  'full  E641743 b',
#  'good   G1487214',
#  'BEAUTI  CHE894556 4',
#  'soft   2156875',
#  'soft   BE2554881',
#  'low   808871',
#  'BEAUTI   CA1553928',
#  'full   1184699',
#  'good   CANT783342 b',
#  'far  663261 b',
#  'flat  WIND2345043',
#  'full   2487568',
#  'hot   BA2435750 b',
#  'hot   225356',
#  'lucky   LON2351975',
#  'warm  824794',
#  'soft  LAU976603',
#  'hot  2506222',
#  'far  RIVER568788 4',
#  'soft   922764',
#  'LARGE   WH2317705 4',
#  'soft   GR1511644',
#  'warm   1948056',
#  nan,
#  'hot   536890 4',
#  'flat   SPRU469117',
#  'low  963112',
#  'sweet   B1079122',
#  'hot   KIM1956274 4',
#  'soft   GREA1005717 4',
#  'lucky  1698795',
#  'sweet   ANDO1348688',
#  'BEAUTI  OB1370160',
#  'BEAUTI  OAK2574353',
#  'warm   54044 b',
#  'rich   INAS1155089 a',
#  'well   L138967',
#  'pleasant   S2488480 4',
#  'hot  FARVI1945079',
#  'full   HIG307908',
#  'soft   CAND1787484',
#  'well   H1157962',
#  'BIG   PON798121',
#  'full   NOR551011',
#  'sweet   CAN409208 b',
#  'low   F1974010',
#  'flat   1977255',
#  'far  150996 4',
#  'BEAUTI   CED2191881',
#  'hot   LOGG14843',
#  'far  2488294',
#  'soft   BROA2348 4',
#  'BEAUTI   LAKE20582',
#  'BEAUTI   B1867888 4',
#  'pleasant   B492617 b',
#  'pleasant  1164372 4',
#  'warm  I1938835',
#  'LARGE   R1023455',
#  'sweet   SUR1108303',
#  'BEAUTI   RIV613773 5',
#  'well  51606 4',
#  'BEAUTI   OL273916',
#  'low   241721',
#  'pleasant  HUC1418729',
#  'hot  HOME2027551',
#  'far   S2199170',
#  'soft  PO1648957 5',
#  'far   BEVE1396910',
#  'soft  N1035802',
#  'warm   RD160034 b',
#  'low   PHE1362237',
#  'well   SO M1347860',
#  'good  1790024',
#  'far  29058 5',
#  'BEAUTI  2618091',
#  'rich  SHER1697469',
#  'warm  6 P1668668',
#  'soft  GLEN2425011 b',
#  'rich  829061',
#  'full  ST2089245 5',
#  'warm  1 A1332016 5',
#  'hot  KENN1642885',
#  'well  KE2232977 5',
#  'lucky  NOBL1538948',
#  'good  RESE2008825',
#  'soft  ALEX1256342',
#  'BEAUTI  CEDAR2437849 b',
#  'pleasant  SYLV1591190',
#  'sweet  7 2350801 5',
#  'soft  E1748258',
#  'full  LE2617971 5',
#  'pleasant  FA175231',
#  'good  1237343 5',
#  'flat  F82577',
#  'sweet  FA1087706',
#  'sweet  F2151959',
#  'full  FFLD1588787 5',
#  'well  R1587873',
#  'far  RESE749438',
#  'flat  RES1192363',
#  'LARGE  201238446',
#  'LARGE  JAN1767821 4',
#  'well  W225195 b',
#  'pleasant  LI483508',
#  'far  ASH1787908',
#  'good  BROA927043',
#  'lucky  DEKA969733',
#  'lucky  JA1762690',
#  'lucky  MOREH1438048',
#  'full  BE2007810',
#  'LARGE  VINC1160723',
#  'good  PARK915162',
#  'hot  CAPIT1111904 a',
#  'far  FAIR2111415',
#  'BEAUTI  E MAI672371',
#  'BEAUTI  CH2180515',
#  'far  GAR1962972 5',
#  'well  FAIRV1318228 4',
#  'flat  2305936',
#  'pleasant  NOBL953342 b',
#  'good  BOST1405802 a',
#  'flat  BO1393180',
#  'good  BOST1377079',
#  'lucky  BRE1357966 4',
#  'hot  B2073468',
#  'good  BREWS1748665',
#  'LARGE  L1262005',
#  'pleasant  141536',
#  'sweet  ALEX2351963',
#  'lucky  CH1837184',
#  'low  R834408',
#  'soft  1216296',
#  'flat  CAN367648 4',
#  'soft  2074179',
#  'LARGE  1783564',
#  'sweet  BON2145229 5',
#  'sweet  GL982164',
#  'well  P294553',
#  'pleasant  1199349 4',
#  'full  560880 5',
#  'well  MAC2208912 a',
#  'far  HORAC1691790',
#  'lucky  NAU481571',
#  'well  FAI618730 a',
#  'warm  NOBL1046837',
#  'far  FAI887932',
#  'good  ANS1135119',
#  'BEAUTI  RIVER420509 a',
#  'sweet  BEA2175726',
#  'low  CA109031 5',
#  'rich  ELM120030',
#  'good  LE1995706 b',
#  'lucky  TREMO1892625 b',
#  'warm  FAI302994',
#  'far  N1161463 5',
#  'full  NORT1938118',
#  'LARGE  614236 5',
#  'well  H1035904',
#  'flat  JA877227',
#  'well  2277531',
#  'pleasant  1261698',
#  'soft  A1946376',
#  'lucky   347977 4',
#  'flat  ASIA2117090 a',
#  'soft  D581378',
#  'sweet  2031634 a',
#  'flat  38452',
#  'warm  CAPIT661385',
#  'low  CAPIT428614 5',
#  'LARGE  CA676628',
#  'flat  MA1599125 4',
#  'LARGE  A1847877',
#  'good  OAK1611033',
#  'pleasant  OLD1078073',
#  'flat  SOUTH1448517 b',
#  'lucky  TRO2366677 5',
#  'well  GUN881502',
#  'soft  CRES775199 b',
#  'pleasant  PATT1279590 4',
#  'good  BRI1174194',
#  'low  WALN2413383',
#  'lucky  ROBI1203845 5',
#  'pleasant  BRADF1041095',
#  'warm  BRAD2612634 4',
#  'good  CO1123116 4',
#  'flat  H1234149 b',
#  'hot  OLD 148091 4',
#  'BEAUTI  SOUTH2002348',
#  'warm  BE2478592',
#  'flat  CO1663678 5',
#  'low  EAST789916 4',
#  'pleasant  R867810 4',
#  'BEAUTI  ROBIN1190172 a',
#  'full  CURRI2207328',
#  'soft  BUDDI137813',
#  'sweet  O2483034 b',
#  'flat  G1192040',
#  'LARGE  E M1553759 b',
#  'far  E MI1046106',
#  'soft  BUDD728859',
#  'warm  PAY613984',
#  'good  PAY818170 b',
#  'low  IVES 1364850',
#  'soft  BUD1160393',
#  'LARGE  & 52344414',
#  'full  MAPLE823821 5',
#  'sweet  PHILS2139247',
#  'good  264286 b',
#  'pleasant  E2509692 5',
#  'lucky  B677761',
#  'far  2019264 4',
#  'pleasant  HIG867060',
#  'good  EAS1921550 5',
#  'hot  1061434',
#  'good  OA863126',
#  'flat  CO457773 5',
#  'lucky  IVES1042882 5',
#  'good  IVES 483612 b',
#  'well  1379547 b',
#  'low  2281023',
#  'warm  OAK 1185045',
#  'hot  RI2162192',
#  'warm  OAK1669148',
#  'low  BLUEF2847 a',
#  'good  1601396 4',
#  'low  GAT1444640',
#  'warm  P1035137',
#  'far  C2343815',
#  'flat  AUTU1936466',
#  'lucky  KENSI2319446',
#  'flat  2578262 b',
#  'lucky  S236262',
#  'flat  783639',
#  'warm  OA188667 5',
#  'LARGE  GLENB1458179',
#  'sweet  WOOD2405078',
#  'hot  MO516606 4',
#  'full  CURRI1267646 a',
#  'far  IVE899702 b',
#  'warm  MAP842866',
#  'low  ALPI1287412',
#  'warm  PAYNE2014951 5',
#  'sweet  S276878',
#  'warm  BUTT979121',
#  'low  C1055993',
#  'LARGE  HUC1758451',
#  'good  HIG2448534 5',
#  'LARGE  RE681218',
#  'soft  876677 5',
#  'warm  MOSS546256',
#  'warm  Q1801479',
#  'warm  WORDE1682011',
#  'good  PACE2206799',
#  'far  PHILS832507 b',
#  'hot  CL449705',
#  'hot  2019789 b',
#  'hot  QU1906081 5',
#  'pleasant  NEW1608077 a',
#  'pleasant  702854',
#  'low  C2623331',
#  'low  S MA266043 4',
#  'low  IVE1420231',
#  'pleasant  WIE21516 a',
#  'warm  YALES303802',
#  'good  CA2518567 b',
#  'low  L1618339 4',
#  'lucky  1284015',
#  'flat  P1442899',
#  'far  S2561651',
#  'sweet  C2630951',
#  'well  QUAR975585 b',
#  'well   MOR1907820',
#  'soft   W1474250',
#  'hot  MADI1376195 5',
#  'full  C1250631 5',
#  'sweet  2476485',
#  'rich   1016465 4',
#  'well  1551826',
#  'pleasant   L1769895',
#  'flat   MY1278868',
#  'soft   BOND508543 b',
#  'LARGE   K2096159',
#  'BEAUTI   VA1845086 4',
#  'LARGE   GRO176290 5',
#  'soft  VIR2448514',
#  'full   2323636',
#  'full  H745332',
#  'hot  575733 5',
#  'BIG   GR1307776',
#  'soft   ROB845730 b',
#  'well  1159108 a',
#  'well   BR2076639',
#  'BEAUTI   OC1684701 b',
#  'well   C2263210 5',
#  'LARGE   F1845122',
#  'pleasant  702615 b',
#  'hot  E2427710',
#  'soft  NO1370596',
#  'good  BO2381344',
#  'well  MAI2482729',
#  'lucky  MADIS1833026 4',
#  'low  1911110 b',
#  'BEAUTI  K241026 a',
#  'good  MAD776857 5',
#  'flat   G1726999',
#  'LARGE  &1205914',
#  'well  MAI2369707',
#  'BIG  W JA878406',
#  'low   21738484',
#  'LARGE  COLON611835',
#  'low  1756112 4',
#  'rich  KING2018793 a',
#  'good   DO532010 a',
#  'rich   D2109044',
#  'pleasant   MA291551',
#  'full  2539329',
#  ...]

# %%
assert os.path.exists('./output_files/task_11.json') == True, (
    "No task_11.json file in the output_files folder"
)
assert type(house_ids_available) == list, (
    "house_ids_available is not list"
)
assert len(house_ids_available) == 26775, (
    "Incorrect number of houses"
)
assert (917505 in house_ids_available) and (131073 in house_ids_available), (
    "Incorrect values in house_ids_available list"
)
print("Tests were passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[62], line 7
#       1 assert os.path.exists('./output_files/task_11.json') == True, (
#       2     "No task_11.json file in the output_files folder"
#       3 )
#       4 assert type(house_ids_available) == list, (
#       5     "house_ids_available is not list"
#       6 )
# ----> 7 assert len(house_ids_available) == 26775, (
#       8     "Incorrect number of houses"
#       9 )
#      10 assert (917505 in house_ids_available) and (131073 in house_ids_available), (
#      11     "Incorrect values in house_ids_available list"
#      12 )
#      13 print("Tests were passed")
#
# AssertionError: Incorrect number of houses

# %% [markdown]
# ### *12. Please find sum of sales_amount by each employee, put the result to excel ('output_files/task_12.xlsx') (emp_id, emp_first_name, emp_last_name, sum(sales_amount)) and mark employees who have less than average sales_amount with red.

# %%
# This task is optional 
# Add you code here
